# %% [markdown]
# <a href="https://colab.research.google.com/github/paulosrl/NotebooksGoogleColab/blob/main/Introdu%C3%A7%C3%A3o_a_an%C3%A1lise_explorat%C3%B3ria_de_dados_(Alugu%C3%A9is_de_im%C3%B3veis_do_Rio_de_Janeiro)_COMPLETO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução a análise exploratória de dados (Aluguéis de imóveis do Rio de Janeiro) - COMPLETO
#
# Autor: Prof. Paulo Lima (paulolima@uepa.br)

# %% [markdown]
# # 1) Importar Bibliotecas necessárias

# %%
# comando para importar uma biblioteca no Python
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 2) Ler os dados de origem e criar o dataframe Imoveis

# %%
# local do arquivo (nuvem)
url = 'https://raw.githubusercontent.com/paulosrl/datasets/master/dbAlugueis.csv'
# comando de leitura para arquivos do tipo "CSV"
df_Imoveis = pd.read_csv(url)

# %% [markdown]
# # 3) Visualizar o resumo dos dados
#
# * `head(n)` - retorna as primeiras n linhas
# * `tail(n)` - retorna as últimas n linhas
# * `sample(n)` - retorna amostra aleatória das n linhas
# * `df` - retorna primeiro e último 5 registros e número de linhas e colunas
# * `df.isnull().sum()` - retorna a quantidade de valores nulos por coluna

# %%
# lista as 3 primeiras linhas do dataframe
df_Imoveis.head(3)
# Out:
#   Tipo;Bairro;Quartos;Vagas;Suites;Area;Valor;Condominio;IPTU
# 0          Quitinete;Copacabana;1;0;0;40;1700;500;60
# 1              Casa;Jardim Botânico;2;0;1;100;7000;;
# 2  Conjunto Comercial/Sala;Barra da Tijuca;0;4;0;...

# %%
# Forma de leitura dos dados já informando o caractere separador
df_Imoveis = pd.read_csv(url, sep=';')

# %%
# lista as 3 primeiras linhas do dataframe
# lista as 3 primeiras linhas do dataframe
df_Imoveis.head(3)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0

# %%
df_Imoveis.tail()
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# 32955    27   800.0       350.0    25.0
# 32956    78  1800.0       800.0    40.0
# 32957    48  1400.0       509.0    37.0
# 32958    70  3000.0       760.0     NaN
# 32959   250  6500.0      4206.0  1109.0

# %%
# lista 4 linhas aleatórias do dataframe
df_Imoveis.sample(4)
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 27961       Casa de Condomínio  Barra da Tijuca        4      5       4  1000
# 18223  Conjunto Comercial/Sala           Tijuca        0      1       0    26
# 22158              Apartamento  Barra da Tijuca        3      2       3   680
# 20788              Apartamento  Barra da Tijuca        4      2       2   300
#
#          Valor  Condominio    IPTU
# 27961  30000.0      2000.0  2670.0
# 18223   1100.0      1300.0     NaN
# 22158  20000.0      2000.0     NaN
# 20788   5500.0      1150.0  7750.0

# %%
# lista o dataframe
df_Imoveis
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
# conta valores nulos por coluna
df_Imoveis.isnull().sum()
# Out:
# Tipo              0
# Bairro            0
# Quartos           0
# Vagas             0
# Suites            0
# Area              0
# Valor            17
# Condominio     4093
# IPTU          10237
# dtype: int64

# %% [markdown]
# ## Observações desta etapa
#
# * É necessário utilizar o delimitador ";" para fazer a leitura correta dos dados;
# * O conjunto de dados possui uma linha de cabeçalho;
# * `NaN` representa valores nulos;
# * As colunasdescription, `condominio e iptu` possuem valores ausentes.

# %% [markdown]
# # 4) Dimensão e tipo de dados do Dataframe
#
# * `df.shape` - retorna a quantidade de linhas e colunas
# * `df.columns` - retorna o nomes das colunas do dataframe
# * `df.info()` e `df.dtypes`- retorna informações sobre os tipos de dados do dataframe

# %%
# lista quantidade de linhas e colunas
df_Imoveis.shape
# Out:
# (32960, 9)

# %%
# lista onome das colunas
df_Imoveis.columns
# Out:
# Index(['Tipo', 'Bairro', 'Quartos', 'Vagas', 'Suites', 'Area', 'Valor',
#        'Condominio', 'IPTU'],
#       dtype='object')

# %%
# lista as características do dataframe
df_Imoveis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# ## Tipo de dados

# %%
def get_var_category(series):
    unique_count = series.nunique(dropna=False)
    total_count = len(series)
    if pd.api.types.is_numeric_dtype(series):
        return 'Numérico'
    elif pd.api.types.is_datetime64_dtype(series):
        return 'Data'
    elif unique_count==total_count:
        return 'Texto (sem repetição de valores)'
    else:
        return 'Categórico'

def lista_Categorias(df):
    for column_name in df.columns:
        print(column_name, ":", get_var_category(df[column_name]))

# %%
# chamada da função
lista_Categorias(df_Imoveis)
# Out:
# Tipo : Categórico
# Bairro : Categórico
# Quartos : Numérico
# Vagas : Numérico
# Suites : Numérico
# Area : Numérico
# Valor : Numérico
# Condominio : Numérico
# IPTU : Numérico

# %%
# lista o tipo de dados do dataframe
df_Imoveis.dtypes
# Out:
# Tipo           object
# Bairro         object
# Quartos         int64
# Vagas           int64
# Suites          int64
# Area            int64
# Valor         float64
# Condominio    float64
# IPTU          float64
# dtype: object

# %% [markdown]
# Colunas do dataFrame

# %%
# listar uma coluna específica do dataframe
df_Imoveis['Tipo']
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
#                   ...
# 32955                  Quitinete
# 32956                Apartamento
# 32957                Apartamento
# 32958                Apartamento
# 32959    Conjunto Comercial/Sala
# Name: Tipo, Length: 32960, dtype: object

# %% [markdown]
# Listar campos específicos do dataFrame

# %%
# listar duas colunas específicas do dataframe
df_Imoveis[['Quartos', 'Valor']]
# Out:
#        Quartos   Valor
# 0            1  1700.0
# 1            2  7000.0
# 2            0  5200.0
# 3            1   800.0
# 4            1   800.0
# ...        ...     ...
# 32955        0   800.0
# 32956        3  1800.0
# 32957        2  1400.0
# 32958        2  3000.0
# 32959        0  6500.0
#
# [32960 rows x 2 columns]

# %% [markdown]
# ## Observações desta etapa
#
# * O dataset contem 32.960 linhas e 2 colunas;
# * O dataset possui 9 colunas:
#   * 6 colunas numéricas;
#   * 3 colunas do tipo catgóricas;
# * O dataset contém os seguintes campos do tipo numérico:
# Quartos, Vagas, Suites, Area, Valor e IPTU;
# * O dataset contém os seguintes campos do tipo categórico:
# Tipo, Bairro e Condominio.

# %% [markdown]
# # 5) Estatística das colunas

# %% [markdown]
# ## Colunas numéricas

# %%
# estatística das colunas numéricas
df_Imoveis.describe()
# Out:
#             Quartos         Vagas        Suites          Area         Valor  \
# count  32960.000000  32960.000000  32960.000000  32960.000000  3.294300e+04
# mean       1.771390      1.749059      0.665777    231.901547  1.295266e+04
# std        1.717869     20.380402      1.176525   1135.254152  6.675220e+05
# min        0.000000      0.000000      0.000000      0.000000  7.500000e+01
# 25%        0.000000      0.000000      0.000000     55.000000  1.500000e+03
# 50%        2.000000      1.000000      0.000000     87.000000  2.800000e+03
# 75%        3.000000      2.000000      1.000000    170.000000  6.500000e+03
# max      100.000000   1966.000000     70.000000  90000.000000  1.200000e+08
#
#          Condominio          IPTU
# count  2.886700e+04  2.272300e+04
# mean   2.388062e+03  2.364410e+03
# std    3.918496e+04  1.795641e+05
# min    1.000000e+00  1.000000e+00
# 25%    5.900000e+02  1.100000e+02
# 50%    9.900000e+02  2.500000e+02
# 75%    1.800000e+03  6.970000e+02
# ...

# %% [markdown]
# ## Histogramas

# %%
# informar o dataframe, coluna e tipo de gráfico: 0 somente histograma, 1 histograma e linha
def geraHistograma(df, coluna, tipo):
  plt.figure(figsize=(10,5))
  sns.set(color_codes=True)
  sns.set_palette(sns.color_palette("muted"))
  if tipo==0:
    sns.histplot(df[coluna].dropna())
  else:
    sns.histplot(df[coluna].dropna(), kde=True);
  return

# %%
# gerar histograma por coluna (rating)
geraHistograma(df_Imoveis,"Suites",0)

# %% [markdown]
# ## Colunas não numéricas

# %%
# estatísticas das colunas não numéricas
df_Imoveis.describe(include='object')
# Out:
#                Tipo           Bairro
# count         32960            32960
# unique           22              162
# top     Apartamento  Barra da Tijuca
# freq          19532             6259

# %% [markdown]
# Existem 22 tipos de imóves e 162 bairros num total de 32.960 linhas.
#
# O imóvel com maior número de ocorrências é o do tipo apartamento.
#
# O bairro com maior número de ocorrências é Barra da Tijuca.

# %% [markdown]
# ## Observações desta etapa
#
# * Existem possíveis outliers na amostra
# por exemplo:
#   * Quartos = 100
#   * Vagas = 1996
#   * Suites = 70
#   * Condomínio = 1
# * Existem campos com valores iguais a 0 (zero):
#   * Quartos = 0
#   * Area = 0
# * Estes valores precisam ser chacados, pois estão influenciando no cálculo da média;
# * Existem 22 tipos de imóves e 162 bairros num total de 32.960 linhas;
# * O imóvel com maior número de ocorrências é o do tipo apartamento;
# * O bairro com maior número de ocorrências é Barra da Tijuca.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 6) Verificar a existência de outliers em colunas numéricas, utilizando Boxplots

# %% [markdown]
# ## Boxplots
# * Gráfico utilizado para representar a distribuição de um conjunto de dados numéricos;
#
# * Utilizado para representar dados quantitativos sendo conveniente para revelar medidas de tendência central, dispersão, distribuição dos dados e a presença de outliers (valores discrepantes).
#
# * Composto por um retângulo central que se estende do primeiro quartil (Q1) ao terceiro quartil (Q3), com uma linha vertical no meio indicando a mediana (Q2);
#
# * As extremidades das linhas que se estendem para fora do retângulo representam o mínimo e o máximo de dados que **não são outliers**;
#
# * Os outliers são marcados por pontos individuais além das extremidades das linhas;
#
# * Pode ser usado para comparar a distribuição de vários conjuntos de dados lado a lado.
#
# * Um boxplot funciona melhor quando o tamanho amostral é a partir de 20.
#
# <br>
# <p align="center"><img src="https://raw.githubusercontent.com/paulosrl/imagens/master/boxplots.png
# "></p>

# %%
# colunas a serem analisadas
cols = ['Quartos','Vagas','Suites','Area','Valor','Condominio','IPTU']
# desenho do gráfico
plt.figure(figsize=(12, 5))
sns.boxplot(data=df_Imoveis[cols], orient='h').set(title='Análise de outliers de: Quartos, Vagas, Suites, Area, Valor, Condominio e IPTU');

# %%
df_Imoveis[cols].describe()
# Out:
#             Quartos         Vagas        Suites          Area         Valor  \
# count  32960.000000  32960.000000  32960.000000  32960.000000  3.294300e+04
# mean       1.771390      1.749059      0.665777    231.901547  1.295266e+04
# std        1.717869     20.380402      1.176525   1135.254152  6.675220e+05
# min        0.000000      0.000000      0.000000      0.000000  7.500000e+01
# 25%        0.000000      0.000000      0.000000     55.000000  1.500000e+03
# 50%        2.000000      1.000000      0.000000     87.000000  2.800000e+03
# 75%        3.000000      2.000000      1.000000    170.000000  6.500000e+03
# max      100.000000   1966.000000     70.000000  90000.000000  1.200000e+08
#
#          Condominio          IPTU
# count  2.886700e+04  2.272300e+04
# mean   2.388062e+03  2.364410e+03
# std    3.918496e+04  1.795641e+05
# min    1.000000e+00  1.000000e+00
# 25%    5.900000e+02  1.100000e+02
# 50%    9.900000e+02  2.500000e+02
# 75%    1.800000e+03  6.970000e+02
# ...

# %%
# análise das coluna Quarto
cols = ['Quartos']
plt.figure(figsize=(20, 5))
sns.boxplot(data=df_Imoveis[cols],orient='h').set(title='Análise de outliers de Quarto');

# %%
# análise das coluna Quartos
df_Imoveis[cols].describe()
# Out:
#             Quartos
# count  32960.000000
# mean       1.771390
# std        1.717869
# min        0.000000
# 25%        0.000000
# 50%        2.000000
# 75%        3.000000
# max      100.000000

# %%
# análise das coluna Vagas
cols = ['Vagas']
plt.figure(figsize=(20, 5))
sns.boxplot(data=df_Imoveis[cols],orient='h').set(title='Análise de outliers de Vagas');

# %%
# análise das coluna Vagas
df_Imoveis[cols].describe()
# Out:
#               Vagas
# count  32960.000000
# mean       1.749059
# std       20.380402
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        2.000000
# max     1966.000000

# %%
# análise das coluna Suites
cols = ['Suites']
plt.figure(figsize=(20, 5))
sns.boxplot(data=df_Imoveis[cols],orient='h').set(title='Análise de outliers de Suites');

# %%
# análise das coluna Suites
df_Imoveis[cols].describe()
# Out:
#              Suites
# count  32960.000000
# mean       0.665777
# std        1.176525
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max       70.000000

# %%
# análise das coluna Area
cols = ['Area']
plt.figure(figsize=(20, 5))
sns.boxplot(data=df_Imoveis[cols],orient='h').set(title='Análise de outliers de Area');

# %%
# análise das coluna Area
df_Imoveis[cols].describe()
# Out:
#                Area
# count  32960.000000
# mean     231.901547
# std     1135.254152
# min        0.000000
# 25%       55.000000
# 50%       87.000000
# 75%      170.000000
# max    90000.000000

# %%
# análise das coluna Valor
cols = ['Valor']
plt.figure(figsize=(20, 5))
sns.boxplot(data=df_Imoveis[cols],orient='h').set(title='Análise de outliers de Valor');

# %%
# análise das coluna Valor
df_Imoveis[cols].describe()
# Out:
#               Valor
# count  3.294300e+04
# mean   1.295266e+04
# std    6.675220e+05
# min    7.500000e+01
# 25%    1.500000e+03
# 50%    2.800000e+03
# 75%    6.500000e+03
# max    1.200000e+08

# %% [markdown]
# ## Observações desta etapa
#
# * Ao analisar várias colunas numéricas ao mesmo tempo, pode não ser possível observar os outliers de algumas colunas;
# * É necessário analisar separadamente cada coluna, ou juntamente as colunas da mesma magnitude;
# * Segundo o boxplot, existem possíveis outliers em todas as colunas;
# * Será necessário analisar os valores extremos nos dados.

# %% [markdown]
# # 7) Inspeção de colunas no dataframe
#
# Neste exemplo iremos escolher a coluna `Tipo`

# %%
# mostra o quantitaivo de valores únicos no dataframe
df_Imoveis.nunique()
# Out:
# Tipo            22
# Bairro         162
# Quartos         20
# Vagas           71
# Suites          15
# Area          1171
# Valor         1414
# Condominio    3811
# IPTU          2765
# dtype: int64

# %%
# conta valores nulos por coluna
df_Imoveis.Tipo.isnull().sum()
# Out:
# 0

# %%
# mostra o quantitativo de valores únicos em um campo
df_Imoveis.Tipo.nunique()
# Out:
# 22

# %%
# lista os valores únicos de um campo
df_Imoveis.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
# cria uma dataframe coim o resumo dos dados
df_grafico=df_Imoveis.Tipo.value_counts(dropna=False).to_frame()

# %%
df_grafico
# Out:
#                               Tipo
# Apartamento                  19532
# Conjunto Comercial/Sala       6815
# Loja/Salão                    1426
# Casa de Condomínio             996
# Casa                           967
# Quitinete                      836
# Galpão/Depósito/Armazém        623
# Flat                           476
# Prédio Inteiro                 301
# Casa Comercial                 265
# Casa de Vila                   249
# Loja Shopping/ Ct Comercial    247
# Box/Garagem                     82
# Terreno Padrão                  70
# Loft                            51
# Sítio                           10
# Loteamento/Condomínio            5
# Studio                           4
# Hotel                            2
# Chácara                          1
# Pousada/Chalé                    1
# Indústria                        1

# %%
# cria um gráfico de barras com as ocorrências da coluna diet
df_grafico.plot(kind='barh', figsize=(10, 5), color ='blue',xlabel ="Quantidade", ylabel="Tipos de Imóvel");

# %% [markdown]
# ## Observações desta etapa
# * Ao observar a coluna Tipo, foi constatado que esta coluna tem 22 valores únicos, o valor mais frequente é "Apartamento" e o menos frequente é "Industria";
#
# * A coluna possui 22 valores únicos;
# * `Apartamento` é o valor mais frequente;
# * Não há valores na coluna Tipo.

# %% [markdown]
# #8) Seleção dos dados

# %% [markdown]
# Iremos separar a base de dados em dois grupos, imóveis comercais e imóveis residenciais.

# %%
# para remover os imóveis comerciais, primeiramente é necessário identicar os tipos únicos de imóveis
# o método "unique" exibe os valores únicos
df_Imoveis.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %% [markdown]
# Separar os tipos de imóveis que não serão analisados (imóveis comerciais)

# %%
# será necessário criar um vetor que contenha todos os tipos de imóveis COMERCIAS APENAS,
# esta selação/criação será feita manualmente, com  os dados inseridos no vetor a seguir
imoveis_comerciais = ['Conjunto Comercial/Sala',
                      'Prédio Inteiro', 'Loja/Salão',
                      'Galpão/Depósito/Armazém',
                      'Casa Comercial', 'Terreno Padrão',
                      'Loja Shopping/ Ct Comercial',
                      'Box/Garagem', 'Chácara',
                      'Loteamento/Condomínio', 'Sítio',
                      'Pousada/Chalé', 'Hotel', 'Indústria']

# %% [markdown]
# Consultar apenas os imóveis comercias (que não serão utilizados)

# %%
# para consultar apenas os imóveis comercias usaremos o método query
df_Imoveis.query('@imoveis_comerciais in Tipo')
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 9      Conjunto Comercial/Sala           Centro        0      3       0   695
# 16              Prédio Inteiro         Botafogo        0      0       0   536
# 26     Conjunto Comercial/Sala    São Cristóvão        0      1       0    25
# 29                  Loja/Salão     Campo Grande        0      1       0    35
# ...                        ...              ...      ...    ...     ...   ...
# 32942  Conjunto Comercial/Sala  Barra da Tijuca        0      1       0    55
# 32946  Conjunto Comercial/Sala           Centro        0      0       0   140
# 32948  Conjunto Comercial/Sala           Centro        0      0       0    32
# 32954              Box/Garagem           Centro        0      0       0   755
# 32959  Conjunto Comercial/Sala           Centro        0      0       0   250
#
# ...

# %% [markdown]
# Consultar apenas imóveis RESIDENCIAIS

# %%
# para consultar apenas os imóveis NÃO comercias (residencias) usaremos o método query usando uma negação no argumento in
df_Imoveis.query('@imoveis_comerciais not in Tipo')
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 32953  Apartamento                 Méier        2      0       0    70
# 32955    Quitinete                Centro        0      0       0    27
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %% [markdown]
# ## Criação do banco de dados de imóveis residencias

# %%
# agora podemos criar um dataframe apenas com os imóveis residencias
df_Residenciais = df_Imoveis.query('@imoveis_comerciais not in Tipo')

# %%
df_Residenciais.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 3  Apartamento           Centro        1      0       0    15   800.0
# 4  Apartamento     Higienópolis        1      0       0    48   800.0
# 5  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 3       390.0  20.0
# 4       230.0   NaN
# 5         NaN   NaN

# %% [markdown]
# ## Criação do banco de dados de apartamentos

# %%
# busca no dataframe "df_Residenciais", somente os imóveis do tipo "Apartamento"
# estes imóveis representam mais de 80% dos imóveis da base dados
df_Residenciais.query("Tipo == 'Apartamento'")
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# 6      Apartamento              Cachambi        2      0       0    50
# 10     Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 32951  Apartamento        Vila Valqueire        2      0       0    52
# 32953  Apartamento                 Méier        2      0       0    70
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 3       800.0       390.0  20.0
# 4       800.0       230.0   NaN
# ...

# %% [markdown]
# Dentro dos imóveis residencias o objeto de análise serão apenas os imóveis residencias do tipo apartamento.

# %%
# criação de um dataframe do tipo apartamentos
df_Apartamentos = df_Residenciais.query("Tipo == 'Apartamento'")

# %%
# 5 primeiros registros do dataframe
df_Apartamentos.head()
# Out:
#            Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3   Apartamento        Centro        1      0       0    15   800.0
# 4   Apartamento  Higienópolis        1      0       0    48   800.0
# 5   Apartamento  Vista Alegre        3      1       0    70  1200.0
# 6   Apartamento      Cachambi        2      0       0    50  1300.0
# 10  Apartamento        Centro        1      0       0    36  1200.0
#
#     Condominio  IPTU
# 3        390.0  20.0
# 4        230.0   NaN
# 5          NaN   NaN
# 6        301.0  17.0
# 10         NaN   NaN

# %% [markdown]
# # 9) Tratando e filtrando os dados

# %% [markdown]
# ## Buscando valores nulos

# %%
df_Apartamentos.isnull().sum()
# Out:
# Tipo             0
# Bairro           0
# Quartos          0
# Vagas            0
# Suites           0
# Area             0
# Valor            7
# Condominio     745
# IPTU          5472
# dtype: int64

# %% [markdown]
# Como as colunas que possuem valores nulos são numéricas, vamos substituir os valores nulos pelo valor zero. Vale ressaltar que nem sempre essa é a melhor abordagem e que esse tratamento de valores nulos sempre irá depender do projeto que estamos trabalhando.
#
# O comando a seguir preenche com zero as colunas que possuem valores nulos.

# %% [markdown]
# ## Preenchendo com Zeros

# %%
df_Apartamentos=df_Apartamentos.fillna(0)

# %% [markdown]
# Verificando o dataframe

# %%
df_Apartamentos.isnull().sum()
# Out:
# Tipo          0
# Bairro        0
# Quartos       0
# Vagas         0
# Suites        0
# Area          0
# Valor         0
# Condominio    0
# IPTU          0
# dtype: int64

# %% [markdown]
# ## Filtrando os dados
#
# Serão removidos os registros cujo o valor do aluguel ou o valor do condomínio seja igual a zero.

# %% [markdown]
# Para encontrar estes registros, utilizaremos o comando a seguir:

# %%
df_Apartamentos.query('Valor == 0 | Condominio == 0')
# Out:
#               Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 5      Apartamento     Vista Alegre        3      1       0    70  1200.0
# 10     Apartamento           Centro        1      0       0    36  1200.0
# 76     Apartamento  Barra da Tijuca        2      1       1    70     0.0
# 113    Apartamento       Praça Seca        2      0       0    80  1000.0
# 166    Apartamento    Rocha Miranda        2      1       0    50  1100.0
# ...            ...              ...      ...    ...     ...   ...     ...
# 32609  Apartamento       Copacabana        3      0       0   130  4600.0
# 32643  Apartamento        Guadalupe        1      0       0    40   550.0
# 32666  Apartamento       Bonsucesso        1      0       0    60  1000.0
# 32708  Apartamento         Flamengo        2      0       0    59  3500.0
# 32809  Apartamento        Cascadura        3      0       1    70  1200.0
#
#        Condominio  IPTU
# 5             0.0   0.0
# 10            0.0   0.0
# ...

# %% [markdown]
# Para armazenar estes registros, será criada uma variável chamada de **registros_a_remover**. Para isso, vamos na célula seguinte e escrevemos:

# %%
registros_a_remover = df_Apartamentos.query('Valor == 0 | Condominio == 0').index

# %% [markdown]
# Na sequência, especificamos um parâmetro chamado de axis que passamos 0 ou 1. O zero significa que desejamos remover linhas, já o 1 significa que queremos remover as colunas. Para o nosso cenário, passamos o número 0 para o parâmetro axis para removermos as linhas.
#
# Logo após vamos especificar mais um parâmetro chamado de inplace passando o valor true. Especificamos esse parâmetro para que essas alterações sejam aplicadas no dataframe, sem precisarmos fazer uma atribuição (colocando df = na frente do código). O inplace faz isso automaticamente para nós.

# %%
df_Apartamentos.drop(registros_a_remover, axis=0, inplace=True)

# %% [markdown]
# Testando resultado

# %%
df_Apartamentos.query('Valor == 0 | Condominio == 0')
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %% [markdown]
# Existe mais algum dado na base de dados que possa ser removido?
#
# Na célula seguinte, escrevemos df.head() para visualizarmos as primeiras linhas do nosso dataframe.

# %%
df_Apartamentos.head()
# Out:
#            Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3   Apartamento               Centro        1      0       0    15   800.0
# 4   Apartamento         Higienópolis        1      0       0    48   800.0
# 6   Apartamento             Cachambi        2      0       0    50  1300.0
# 11  Apartamento               Grajaú        2      1       0    70  1500.0
# 12  Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
#
#     Condominio  IPTU
# 3        390.0  20.0
# 4        230.0   0.0
# 6        301.0  17.0
# 11       642.0  74.0
# 12       455.0  14.0

# %% [markdown]
# Verificando os valores que existem na coluna tipo.

# %%
df_Apartamentos.Tipo.unique()
# Out:
# array(['Apartamento'], dtype=object)

# %% [markdown]
# Ele nos informa que o único valor existente na coluna "Tipo" é o apartamento. Logo, podemos remover também essa coluna usando o método drop(). Escrevemos na célula seguinte df.drop('Tipo', axis=1, inplace=True).

# %%
df_Apartamentos.drop('Tipo', axis=1, inplace=True)

# %%
df_Apartamentos.head()
# Out:
#                  Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 3                Centro        1      0       0    15   800.0       390.0
# 4          Higienópolis        1      0       0    48   800.0       230.0
# 6              Cachambi        2      0       0    50  1300.0       301.0
# 11               Grajaú        2      1       0    70  1500.0       642.0
# 12  Lins de Vasconcelos        3      1       1    90  1500.0       455.0
#
#     IPTU
# 3   20.0
# 4    0.0
# 6   17.0
# 11  74.0
# 12  14.0

# %%
# análise das colunas
df_Apartamentos[cols].describe()
# Out:
#               Valor
# count  1.878000e+04
# mean   4.805296e+03
# std    3.491848e+04
# min    1.000000e+02
# 25%    1.700000e+03
# 50%    2.800000e+03
# 75%    5.000000e+03
# max    4.500000e+06

# %%
# apenas apartamentos com condomínio menor que 2000
df_Apartamentos = df_Apartamentos.query('Condominio <=2000')

# %%
# análise das colunas
df_Apartamentos[cols].describe()
# Out:
#               Valor
# count  1.562300e+04
# mean   3.456236e+03
# std    3.796802e+04
# min    1.000000e+02
# 25%    1.500000e+03
# 50%    2.400000e+03
# 75%    3.700000e+03
# max    4.500000e+06

# %%
# colunas a serem analisadas
cols = ['Quartos','Vagas','Suites','Area','Valor','Condominio','IPTU']
# desenho do gráfico
plt.figure(figsize=(12, 5))
sns.boxplot(data=df_Apartamentos[cols], orient='h').set(title='Análise de outliers de: Quartos, Vagas, Suites, Area, Valor, Condominio e IPTU');

# %% [markdown]
# # 10) Salvando os dados

# %% [markdown]
# ## Formato CSV

# %%
df_Apartamentos.to_csv('dados_apartamentos.csv',index=False, sep=";")

# %% [markdown]
# ## FormatoEXCEL

# %%
df_Apartamentos.to_excel('dados_apartamentos.xlsx',index=False)

# %% [markdown]
# # 11) Inserindo dados

# %% [markdown]
# ## Criando um coluna numérica Valor por mês, esta coluna será igual ao valor do aluguel mais o valor do condomínio

# %%
df_Apartamentos['Valor_por_mes'] = df_Apartamentos['Valor'] + df_Apartamentos['Condominio']

# %%
# visualizando o dataframe
df_Apartamentos.head()
# Out:
#                  Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 3                Centro        1      0       0    15   800.0       390.0
# 4          Higienópolis        1      0       0    48   800.0       230.0
# 6              Cachambi        2      0       0    50  1300.0       301.0
# 11               Grajaú        2      1       0    70  1500.0       642.0
# 12  Lins de Vasconcelos        3      1       1    90  1500.0       455.0
#
#     IPTU  Valor_por_mes
# 3   20.0         1190.0
# 4    0.0         1030.0
# 6   17.0         1601.0
# 11  74.0         2142.0
# 12  14.0         1955.0

# %% [markdown]
# ## Criando um coluna numérica Valor por ano, esta coluna será igual ao valor do aluguel multiplicado por 12 mais o valor do IPTU

# %%
df_Apartamentos['Valor_por_ano'] = df_Apartamentos['Valor'] * 12 + df_Apartamentos['Condominio'] * 12 + df_Apartamentos['IPTU']

# %%
# visualizando o dataframe
df_Apartamentos.head()
# Out:
#                  Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 3                Centro        1      0       0    15   800.0       390.0
# 4          Higienópolis        1      0       0    48   800.0       230.0
# 6              Cachambi        2      0       0    50  1300.0       301.0
# 11               Grajaú        2      1       0    70  1500.0       642.0
# 12  Lins de Vasconcelos        3      1       1    90  1500.0       455.0
#
#     IPTU  Valor_por_mes  Valor_por_ano
# 3   20.0         1190.0        14300.0
# 4    0.0         1030.0        12360.0
# 6   17.0         1601.0        19229.0
# 11  74.0         2142.0        25778.0
# 12  14.0         1955.0        23474.0

# %% [markdown]
# ## Criando uma coluna chamada "Descricao" como descrição do anúncio: a coluna descrição deverá estar no seguinte formato:
#
# "Apartamento em <bairro> com <xx> quarto(s) e <xx> vaga(s) de garagem".

# %%
#Perceba que estamos utilizando barra invertida \ para quebrar linha e facilitar a visualização do comando.
#Ao executar, note que temos um TypeError, porque não é possível concatenar strings com números inteiros,
#que é o caso das colunas numéricas de quartos e vagas. Sendo assim, é necessário converter essas informações
#para string usando o método .asType() e informando para qual tipo será feita a conversão.

df_Apartamentos['Descricao'] = 'Apartamento em ' + df_Apartamentos['Bairro'] + ' com ' + \
                                        df_Apartamentos['Quartos'].astype(str) + ' quarto(s) ' + \
                                        ' e ' + df_Apartamentos['Vagas'].astype(str) + ' vaga(s) de garagem.'

# %%
df_Apartamentos.head()
# Out:
#                  Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 3                Centro        1      0       0    15   800.0       390.0
# 4          Higienópolis        1      0       0    48   800.0       230.0
# 6              Cachambi        2      0       0    50  1300.0       301.0
# 11               Grajaú        2      1       0    70  1500.0       642.0
# 12  Lins de Vasconcelos        3      1       1    90  1500.0       455.0
#
#     IPTU  Valor_por_mes  Valor_por_ano  \
# 3   20.0         1190.0        14300.0
# 4    0.0         1030.0        12360.0
# 6   17.0         1601.0        19229.0
# 11  74.0         2142.0        25778.0
# 12  14.0         1955.0        23474.0
#
#                                             Descricao
# 3   Apartamento em Centro com 1 quarto(s)  e 0 vag...
# 4   Apartamento em Higienópolis com 1 quarto(s)  e...
# 6   Apartamento em Cachambi com 2 quarto(s)  e 0 v...
# 11  Apartamento em Grajaú com 2 quarto(s)  e 1 vag...
# ...

# %% [markdown]
# ## Criando uma coluna "possui_suite", coluna binária que conterá os valores True ou False.

# %%
#Para criá-la, precisamos analisar a coluna já existente que possui a quantidade de suítes em cada
# um dos imóveis. Sendo assim, teremos que analisar cada linha dessa coluna e colocar "Sim"
# para as que tiverem valor maior que zero, e "Não" para o caso contrário.

#Neste comando, usamos o método .apply(), utilizado para aplicar uma determinada função em um conjunto
#específico de dados. No nosso caso, esse conjunto é a coluna "Suites", e a função, é do tipo
#lambda - funções personalizadas que podem ser escritas em uma única linha.

#Nesta função, x equivale a cada linha da coluna de suítes. Então, fizemos uma condicional
#if em que se o valor de x, ou seja, o registro da linha, for maior que zero, deve ser colocado "Sim",
#caso contrário (else), coloca-se "Não".

df_Apartamentos['Possui_suite'] = df_Apartamentos['Suites'].apply(lambda x: "Sim" if x > 0 else "Não")

# %%
df_Apartamentos.head()
# Out:
#                  Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 3                Centro        1      0       0    15   800.0       390.0
# 4          Higienópolis        1      0       0    48   800.0       230.0
# 6              Cachambi        2      0       0    50  1300.0       301.0
# 11               Grajaú        2      1       0    70  1500.0       642.0
# 12  Lins de Vasconcelos        3      1       1    90  1500.0       455.0
#
#     IPTU  Valor_por_mes  Valor_por_ano  \
# 3   20.0         1190.0        14300.0
# 4    0.0         1030.0        12360.0
# 6   17.0         1601.0        19229.0
# 11  74.0         2142.0        25778.0
# 12  14.0         1955.0        23474.0
#
#                                             Descricao Possui_suite
# 3   Apartamento em Centro com 1 quarto(s)  e 0 vag...          Não
# 4   Apartamento em Higienópolis com 1 quarto(s)  e...          Não
# 6   Apartamento em Cachambi com 2 quarto(s)  e 0 v...          Não
# ...

# %% [markdown]
# ## Salvando os dados em Excel

# %%
df_Apartamentos.to_excel('dados_apartamentos_2.xlsx',index=False)

# %% [markdown]
# # 12) Análise para imóveis do tipo apartamento

# %% [markdown]
# ## Qual a média de quartos por apartamento?

# %%
# cálculo da média da quantidade de quartos dos imóveis do tipo apartamento
df_Apartamentos['Quartos'].mean()
# Out:
# 2.3084554823017345

# %% [markdown]
# ## Quantos bairros únicos existem na base de dados?

# %%
# Uma das formas de conferir quantos bairros únicos existem na base de dados,
# seria utilizando o método unique(), que vai nos retornar uma lista com
# os bairros únicos. E logo em seguida utilizar a função len, para contar
# quantos elementos existem nessa lista:
len(df_Apartamentos['Bairro'].unique())
# Out:
# 144

# %%
# Outra forma para realizar o mesmo cálculo, é utilizar um método do próprio
# da biblioteca Pandas que faz a contagem de elementos únicos de uma coluna
# específica de forma direta. Esse método é o nunique():
df_Apartamentos['Bairro'].nunique()
# Out:
# 144

# %% [markdown]
# ## Quais bairros possuem a média do valor de aluguel mais elevadas?

# %%
# agrupar nossa base de dados de acordo com a coluna Bairro
# aplicar o método mean
# colocar o resultado em um DataFrame e ordená-lo
# o parâmetro ascending=False é usado na função sort_values()
# para ordenar os valores em ordem decrescente (do maior para o menor).

df_Apartamentos.groupby('Bairro')[['Valor']].mean().sort_values('Valor')
# Out:
#                         Valor
# Bairro
# Paciência          510.000000
# Cosmos             557.142857
# Santa Cruz         590.000000
# Cavalcanti         590.000000
# Guaratiba          600.000000
# ...                       ...
# Leblon            5779.679296
# Ipanema           5936.176972
# Jardim Oceânico   6406.666667
# Botafogo          9456.360700
# Cidade Jardim    12000.000000
#
# [144 rows x 1 columns]

# %% [markdown]
# ## Gráfico de barras verticais com 5 maiores valores médios de aluguel por bairro

# %%
# Para criar um gráfico com apenas os 5 bairros que possuem a média de aluguel
# mais elevada, podemos utilizar o .head() para selecionar as 5 primeiras linhas
# do DataFrame criado e salvar em uma variável
df_Apartamentos.groupby('Bairro')[['Valor']].mean().sort_values('Valor').tail()
# Out:
#                         Valor
# Bairro
# Leblon            5779.679296
# Ipanema           5936.176972
# Jardim Oceânico   6406.666667
# Botafogo          9456.360700
# Cidade Jardim    12000.000000

# %%
#Em seguida, podemos criar o gráfico:
df_bairros = df_Apartamentos.groupby('Bairro')[['Valor']].mean().sort_values('Valor').tail()
df_bairros.plot(kind='barh', figsize=(10,5), color='blue');

# %% [markdown]
# ## Apartamentos que possuem `1 quarto` e `aluguel menor que 1200`

# %%
#consulta 1
# 1 quarto e aluguel menor 1200
df_Apartamentos.query('Quartos == 1 & Valor < 1200')
# Out:
#              Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio   IPTU  \
# 3            Centro        1      0       0    15   800.0       390.0   20.0
# 4      Higienópolis        1      0       0    48   800.0       230.0    0.0
# 28           Tijuca        1      0       0    48   750.0       772.0   25.0
# 54           Centro        1      0       0    27   750.0       371.0   19.0
# 94           Centro        1      1       0    37  1100.0       540.0  900.0
# ...             ...      ...    ...     ...   ...     ...         ...    ...
# 32596        Grajaú        1      0       1    37  1000.0       200.0    0.0
# 32617     Pechincha        1      0       1    69   900.0       640.0  126.0
# 32627        Glória        1      0       0    46  1100.0       453.0   32.0
# 32714      Botafogo        1      0       0    21  1000.0       282.0   25.0
# 32950        Tijuca        1      0       0    28  1000.0       360.0   25.0
#
#        Valor_por_mes  Valor_por_ano  \
# ...

# %% [markdown]
# ## `Apartamentos` que possuem pelo menos `2 quartos`, `aluguel menor que 3000` e `area maior que 70`

# %%
#consulta 2
# 2 quartos, aluguel menor 3000 e area > 70
df_Apartamentos.query('Quartos == 2 & Valor < 3000 & Area > 70')
# Out:
#                          Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 21                       Tijuca        2      1       0   110  1900.0
# 24                       Tijuca        2      1       0    78  2000.0
# 32                     Botafogo        2      1       0    76  2500.0
# 57     Recreio dos Bandeirantes        2      1       2    83  1600.0
# 67                     Maracanã        2      0       0    86  1800.0
# ...                         ...      ...    ...     ...   ...     ...
# 32881                   Taquara        2      1       1    71  1300.0
# 32890   Freguesia (Jacarepaguá)        2      1       1    87  1300.0
# 32933  Recreio dos Bandeirantes        2      1       1   105  2100.0
# 32934               Jacarepaguá        2      1       1    78  2200.0
# 32940           Barra da Tijuca        2      1       1    85  2250.0
#
#        Condominio   IPTU  Valor_por_mes  Valor_por_ano  \
# 21          700.0  138.0         2600.0        31338.0
# ...

# %% [markdown]
# #13) Análise do valor médio do aluguel de todos os imóveis

# %% [markdown]
# ## Qual a média dos valores de todas colunas numéricas por tipo de imóvel?

# %%
# aqui calcula a média de todos os valores independete do tipo de imóvel
df_Imoveis['Valor'].mean()
# Out:
# 12952.659715265761

# %%
# para calcular o valor por tipo de imóvel, será necessário agrupar o dataframe
# para isso será necessário utilizar um método de agrupamento chamado groupby
# seguido de uma função de cálculo, que neste exemplo é a média
# o parâmetro "numeric_only=True" é utilizado para que o cálculo seja aplicado apenas
# nas colunas de valores numéricos.

#observar que foram calculadas as médias de todas as colunas numéricas

df_Imoveis.groupby("Tipo").mean(numeric_only=True)
# Out:
#                                Quartos      Vagas     Suites          Area  \
# Tipo
# Apartamento                   2.481569   1.232388   0.875998    119.790498
# Box/Garagem                   0.060976   1.304878   0.000000     17.524390
# Casa                          3.133402   1.795243   1.258532    250.578077
# Casa Comercial                1.562264   2.203774   0.260377    372.241509
# Casa de Condomínio            4.007028   3.101406   2.864458    456.161647
# Casa de Vila                  1.927711   0.389558   0.228916     78.469880
# Chácara                       3.000000   0.000000   0.000000      0.000000
# Conjunto Comercial/Sala       0.040939   2.516801   0.010858    214.472487
# Flat                          1.415966   0.962185   0.754202     65.483193
# Galpão/Depósito/Armazém       0.043339   5.587480   0.000000   2514.810594
# Hotel                        25.500000   2.500000  12.000000    885.500000
# ...

# %% [markdown]
# ##Qual o valor médio de aluguel por tipo de imóvel?

# %%
# cálculo do valor médio do aluguel por tipo de imóvel
df_Imoveis.groupby("Tipo")["Valor"].mean()
# Out:
# Tipo
# Apartamento                      4744.614648
# Box/Garagem                      1899.756098
# Casa                             6793.454922
# Casa Comercial                  14478.264151
# Casa de Condomínio              11952.061245
# Casa de Vila                     1574.369478
# Chácara                          4900.000000
# Conjunto Comercial/Sala         14715.045521
# Flat                             4546.189076
# Galpão/Depósito/Armazém         53407.062600
# Hotel                           25000.000000
# Indústria                      120000.000000
# Loft                             2557.882353
# Loja Shopping/ Ct Comercial      8126.178862
# Loja/Salão                      13769.646770
# Loteamento/Condomínio           22000.000000
# Pousada/Chalé                    1480.000000
# Prédio Inteiro                 498637.239203
# Quitinete                        1246.840909
# Studio                           2400.000000
# Sítio                           12499.000000
# ...

# %% [markdown]
# ### Transformar o resultado anterior em um dataframe e ordenar os resultados em ordem crescente de valores.

# %%
# para transformar a saída em um dataframe, acrescenta-se outros dois colchetes a coluna Valor
# para ordenar o resultado, utiliza-se o método sort_values com o parâmetro desejado para classificação
df_Imoveis.groupby("Tipo")[["Valor"]].mean().sort_values('Valor')
# Out:
#                                      Valor
# Tipo
# Quitinete                      1246.840909
# Pousada/Chalé                  1480.000000
# Casa de Vila                   1574.369478
# Box/Garagem                    1899.756098
# Studio                         2400.000000
# Loft                           2557.882353
# Flat                           4546.189076
# Apartamento                    4744.614648
# Chácara                        4900.000000
# Casa                           6793.454922
# Loja Shopping/ Ct Comercial    8126.178862
# Casa de Condomínio            11952.061245
# Sítio                         12499.000000
# Loja/Salão                    13769.646770
# Casa Comercial                14478.264151
# Conjunto Comercial/Sala       14715.045521
# Loteamento/Condomínio         22000.000000
# Hotel                         25000.000000
# Terreno Padrão                32567.714286
# Galpão/Depósito/Armazém       53407.062600
# Indústria                    120000.000000
# ...

# %% [markdown]
# Valores de aluguel por tipo de imóvel.

# %%
# para criar este gráfico, será necessário criar um dataframe apenas com os dados que serão plotados,
# para isso, será criado um outro dataframe chamado dbImoveisGrafico, utilizando mesmo comando executado anteriormente
df_ImoveisGrafico = df_Imoveis.groupby("Tipo")[["Valor"]].mean().sort_values('Valor')

# %%
# plota um gráfico horizontal, tipo de barras horizontais, nas dimensões 10h X 5v, na cor verde
df_ImoveisGrafico.plot(kind='barh', figsize=(12, 10), color ='green');

# %% [markdown]
# ## Existe alguma tendência nos dados ?
#
# Algum tipo de imóvel se destaca muito mais que outros ?
#
# É necessário dividir os dados para análise ? Por que ?

# %% [markdown]
# # 14) Análise do valor médio de aluguel por tipo de imóvel residencial

# %%
# criacao do dataframe que será utilizado (processado) para plotar o gráfico
df_ResidenciaisGrafico = df_Residenciais.groupby("Tipo")[["Valor"]].mean().sort_values('Valor')

# %%
# Média do valor do aluguel por tipo de imóvel residencial
# plota um gráfico horizontal, tipo de barras horizontais, nas dimensões 10h X 5v, na cor verde
df_ResidenciaisGrafico.plot(kind='barh', figsize=(10, 5), color ='green');

# %%
# colunas a serem analisadas
cols = ['Quartos','Vagas','Suites','Area','Valor','Condominio','IPTU']
# desenho do gráfico
plt.figure(figsize=(12, 5))
sns.boxplot(data=df_Residenciais[cols], orient='h').set(title='Análise de outliers de Imóveis residenciais: Quartos, Vagas, Suites, Area, Valor, Condominio e IPTU');

# %%
df_Residenciais[cols].describe()
# Out:
#             Quartos         Vagas        Suites          Area         Valor  \
# count  23111.000000  23111.000000  23111.000000  23111.000000  2.310200e+04
# mean       2.483752      1.276492      0.936610    134.771278  4.970866e+03
# std        1.106639     12.942293      1.131588    144.142878  3.207941e+04
# min        0.000000      0.000000      0.000000     10.000000  1.000000e+02
# 25%        2.000000      0.000000      0.000000     63.000000  1.555000e+03
# 50%        2.000000      1.000000      1.000000     89.000000  2.700000e+03
# 75%        3.000000      2.000000      1.000000    150.000000  5.300000e+03
# max       32.000000   1960.000000     14.000000   3000.000000  4.500000e+06
#
#          Condominio           IPTU
# count  2.124600e+04   16232.000000
# mean   1.648800e+03     789.994209
# std    4.511732e+04    4427.156521
# min    1.000000e+00       1.000000
# 25%    5.800000e+02      98.000000
# 50%    9.500000e+02     222.000000
# ...

# %% [markdown]
# ## Qual a quantidade de imóveis por tipo de imóvel na base de dados?

# %%
# para obter o total por tipo utizaremos o método value_counts
# o resultado será o total por tipo de imóvel
df_Residenciais.Tipo.value_counts()
# Out:
# Apartamento           19532
# Casa de Condomínio      996
# Casa                    967
# Quitinete               836
# Flat                    476
# Casa de Vila            249
# Loft                     51
# Studio                    4
# Name: Tipo, dtype: int64

# %% [markdown]
# ## Qual o percentual de cada tipo de imóvel na base de dados?

# %%
# para obter os valores percentuais, devemos utilizar o mesmo método value_counts com
# o parâmetro "normalize=True"
df_Residenciais.Tipo.value_counts(normalize=True)
# Out:
# Apartamento           0.845139
# Casa de Condomínio    0.043096
# Casa                  0.041842
# Quitinete             0.036173
# Flat                  0.020596
# Casa de Vila          0.010774
# Loft                  0.002207
# Studio                0.000173
# Name: Tipo, dtype: float64

# %% [markdown]
# Criação de uma dataFrame para estudo dos imóveis por percentual

# %%
# vamos criar um dataframe específico para armazenar os valores calculados em percentual
# exibidos em ordem crescente, será necessário utilizar os métodos
# to_frame (converter em dataframe) e sort_values (ordenar os valores)
df_PercentualTipo=df_Residenciais.Tipo.value_counts(normalize=True).to_frame().sort_values("Tipo")

# %%
# renomear uma coluna do dataframe
df_PercentualTipo.rename(columns={'Tipo': 'Percentuais'}, inplace=True)
df_PercentualTipo
# Out:
#                     Percentuais
# Studio                 0.000173
# Loft                   0.002207
# Casa de Vila           0.010774
# Flat                   0.020596
# Quitinete              0.036173
# Casa                   0.041842
# Casa de Condomínio     0.043096
# Apartamento            0.845139

# %%
# Gráfico plotado com os valores calculados em percentual
df_PercentualTipo.plot(kind="bar",figsize=(10, 5), color ='blue', xlabel ="Tipos", ylabel="Percentual");
