# %% [markdown]
# <a href="https://colab.research.google.com/github/paulosrl/NotebooksGoogleColab/blob/main/Converte_Endereco_para_Coordenada_GPS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.0 MB 8.3 MB/s
# ...
#      |████████████████████████████████| 16.7 MB 48.7 MB/s
# ...
#      |████████████████████████████████| 6.3 MB 43.0 MB/s
# ...

# %%
import geopandas as gpds
import pandas as pd

# %%
gpds.tools.geocode("Belém,PA", provider='nominatim',user_agent="my-application")
# Out:
#                      geometry  \
# 0  POINT (-48.46825 -1.45056)
#
#                                              address
# 0  Belém, Região Geográfica Imediata de Belém, Re...

# %%
df = pd.read_excel("AGENCIAS.xlsx")

# %%
df.head()
# Out:
#    CNPJ        SEQUENCIAL DO CNPJ  DV DO CNPJ  \
# 0  00.000.000                   2          72
# 1  00.000.000                   3          53
# 2  00.000.000                   4          34
# 3  00.000.000                   5          15
# 4  00.000.000                   6           4
#
#   NOME INSTITUIÇÃO                                                                                                                                                                                          \
# 0  BANCO DO BRASIL S.A.                          ...
# 1  BANCO DO BRASIL S.A.                          ...
# 2  BANCO DO BRASIL S.A.                          ...
# 3  BANCO DO BRASIL S.A.                          ...
# 4  BANCO DO BRASIL S.A.                          ...
#
#   SEGMENTO                                                      CÓD COMPE AG  \
# 0  Banco do Brasil - Banco Múltiplo              ...                       2
# ...

# %%
gpds.tools.geocode(df['ENDEREÇO                                '], provider='google',user_agent="my-application")
# Out:
# /usr/local/lib/python3.7/dist-packages/geopy/geocoders/googlev3.py:122: UserWarning: Since July 2018 Google requires each request to have an API key. Pass a valid `api_key` to GoogleV3 geocoder to hide this warning. See https://developers.google.com/maps/documentation/geocoding/usage-and-billing
#   UserWarning
#                        geometry address
# 0      GEOMETRYCOLLECTION EMPTY    None
# 1      GEOMETRYCOLLECTION EMPTY    None
# 2      GEOMETRYCOLLECTION EMPTY    None
# 3      GEOMETRYCOLLECTION EMPTY    None
# 4      GEOMETRYCOLLECTION EMPTY    None
# ...                         ...     ...
# 17999  GEOMETRYCOLLECTION EMPTY    None
# 18000  GEOMETRYCOLLECTION EMPTY    None
# 18001  GEOMETRYCOLLECTION EMPTY    None
# 18002  GEOMETRYCOLLECTION EMPTY    None
# 18003  GEOMETRYCOLLECTION EMPTY    None
#
# [18004 rows x 2 columns]
