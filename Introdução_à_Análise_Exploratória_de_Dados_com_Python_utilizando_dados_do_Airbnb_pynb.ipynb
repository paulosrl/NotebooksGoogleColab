# %% [markdown]
# <a href="https://colab.research.google.com/github/paulosrl/NotebooksGoogleColab/blob/main/Introdu%C3%A7%C3%A3o_%C3%A0_An%C3%A1lise_Explorat%C3%B3ria_de_Dados_com_Python_utilizando_dados_do_Airbnb_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introdução à Análise Exploratória de Dados com Python utilizando dados do Airbnb**
# ---
# Pesquisa e Desenvolvimento: [Paulo Lima](https://paulolima.net.br)

# %% [markdown]
# ### **Referencial teórico**

# %% [markdown]
# #### Introdução

# %% [markdown]
# Um dos primeiros desafios de um Cientista de Dados é conhecer os dados que serão analisados. É importante entender o significado exato de cada coluna que compõem o conjunto de dados, analisar ainda se estão no formato correto, se possuem ou não relacionamento, se existem valores faltantes ou nulos, se existem valores duplicados e finalmente decidir sobre a qualidade do dados. A qualidade dos dados é um requisito fundamental para que o processo de tomada de decisão possa ocorrer de forma segura.
#
# Entre as principais tarefas na análise exploratória de dados, podemos destacar a busca por valores ausentes, detecção outliers e a transformação dos dados. A Análise Exploratória de Dados (AED) utiliza, ante de utilizar qualquer técnica estatística ou de visualização de dados.
#
# AED não se trata apenas de elaborar visualizações sofisticadas, toda visualização de dados tem como base os dados, se esses dados não foram previamente checados ou aferidos, teremos uma projeção desastrosa. O objetivo é fazer testes e simulações com os dados buscando dar as respostas mais precisas o possível com os dados previamente analisados.
#
# Este notebook, foi desenvolvido utilizando as principais técnicas e ferramentas para fazer AED. Serão descritas as principais tarefas da AED, começando por entender as colunas de dados, criando um dicionário resumido dos dados, em seguida a análise de cada coluna, ou as colunas que são o objeto de interesse. Em seguida uma análise das principais medidas de resumo numérico, busca por valores discrepante conhecidos como outliers. Utilizaremos aqui uma das técnicas para detecção de outliers, conhecida como Intervalo Interquartílico (IQR - Interquartile Range) e o processo será apoiado por gráficos dinâmicos que facilitam o processo da exploração dos dados.
#
# O notebook utiliza como exemplo os dados disponibilizados pela plataforma Airbnb, esses dados são relativos aos imóveis disponíveis para locação.
#
# Os dados analisados são referentes ao estado norte americano do Havaí, localizado em um arquipélago no Oceano Pacífico. É o oitavo menor estado norte americano em área. O arquipélago possui 132 ilhas que se estendem por 2.450 km. A maior parte do Estado concentra-se no sudeste do arquipélago, onde estão as oito maiores ilhas do Havaí. Os dados são descritos de forma resumida na seção dicionário de dados.

# %% [markdown]
# #### Dados de entrada
#
# **Dados brutos**
#
# * Quando fazemos uma coleta de dados, e armazenamos de forma correta, temos em mãos o que se chama de **dados brutos**, pois consiste das observações **“puras”**, sem **nenhum** tipo de processamento ou resumo;
#
# * A análise de dados deve começar **sempre** pela análise dos dados **brutos**, é a partir desses dados que serão tomadas as primeiras decisões do que será feito com a amostra. A qualidade de dados é fundamental para uma boa análise, pois permitem uma análise precisa do que se está analisando.
#
# **Convenções para os dados de entrada**
#
# * Os dados devem estar no formato de **matriz** (linha x coluna);
# * Cada linha da matriz corresponde a **uma** unidade experimental (**elemento** da **população** ou **amostra** no qual observamos as variáveis/**colunas** da tabela);
# * Cada **coluna** da matriz corresponde a uma **variável**;

# %% [markdown]
# #### O processo de análise e tratamento dos dados
#
# Antes de começar qualquer análise é necessário **validar os dados**, este processo permitirá ao analista conhecer **melhor** os dados que serão analisados.
#
# Esta validação é de extrema importância, pois a **qualidade dos dados** irá impactar **diretamente** na **visualização**, inclusive para construção de modelos de algoritmos que poderão utilizar em uma fase posterior técnicas de Inteligência Artificial, como por exemplo o aprendizado de máquina (*Machine Learning*).
#
# Entre as habilidades básicas de um Cientista de Dados, podemos destacar:
#
# * Tratar valores ausentes;
#
# * Tratar valores repetidos;
#
# * Tratar valores discrepantes (*outliers*);
#
# * Em caso de necessidade, transformar os dados para formatos mais adequados para o processamento.
#
# **Tratamento dos dados**
#
# Nesta etapa deverá ser definido como serão tratados os dados brutos, sobre os seguintes aspectos:
#
# * Quais são as variáveis que se tem interesse em analisar;
# * Verificar se existem outliers na amostra, e o que será feito com eles;
# * Definir se haverá algum ponto de corte nos dados, em caso afirmativo informar que houve um corte nos dados e porque a decisão de cortar esses dados foi tomada;
# * Definir se serão inseridos valores em colunas ausentes ou nulas, ou se essas linhas que contém valores ausentes serão eliminadas da análise e explicar porque a decisão foi tomada;
# * Em caso de optar pela não eliminação das linhas, informar como serão inseridos os valores faltantes (de forma artificial). Informar se serão inseridos utilizando a média, a mediana ou a moda da  coluna com os valores faltantes.
#
# Este processe deverá ser feito com bastante cautela, pois algumas variáveis onde o volume é muito grande, qualquer tipo de preenchimento pode **enviesar** os dados de forma que a análise deixasse de ser relevante.
#
# **Avaliação inicial dos dados**
#
# Consiste em checar, primeiramente cada coluna que compõe o conjunto de dados e finalmente as linhas desse conjunto de dados, analisando principalemente os seguintes itens:
#
# * **O Tipo de Dados**
#   * Coluna de data deve estar em formato `datetime`
#   * Coluna de valores monetários deve estar no formato `float` (utilizando casas decimais)
# * **O intervalo dos Dados**
#   * Meses devem possuir valores que estão entre 1 a 12
#   * Dias do mês devem possuir valores que estão entre 1 a 31
# * **Quais os dados que são obrigatórios**
#   * Algumas colunas não podem estar vazias
# * **Quais os dados que são únicos**
#   * CPF, RG, CNPJ, ID de usuário
# * **Quais os dados categóricos**
#   * Gênero Masculino ou Feminino
# * **Os dados estão no padrão esperado**
#   * (61) 98765-4321
# * **A validade entre os campos que compõem a base de dados**
#   * Data de saída não poder ser anterior à data de entrada.
# * **Existem valores nulos em colunas importantes?**
# * **Existem linhas repetidas, em caso afirmativo essas linhas deverão ser excluídas pois trata-se de um erro.**
#
# **Valores ausentes**
#
# Caso existam valores ausente no conjunto de dados, decidir se é ou não possível realizar a análise. Esses valores poderão eliminados ou substituídos por exemplo, pela média, mediana, moda ou qualquer outra medida.
#
# Em caso de exclusão de linhas do conjunto de dados, é importante calcular o percentual que esses valores eliminados representam em relação ao todo que será analisado.
#
# Decisões a serem tomadas sobre os dados ausentes:
#
# * **Excluir**
#   * Se os dados ausentes estão em **pequeno** número, ocorrem **aleatoriamente**, e a ausência não acarreta nenhum problema, é melhor **excluir** a linha;
#
# * **Preencher**
#   * Preencher as entradas com dados ausentes com valores estatísticos como a **média, mediana, moda ou zeros**.
#   * A **média** é mais útil quando a distribuição dos dados é **normal**.
#   * Em dados com distribuição mais enviesada (*skewed*), a **mediana** é uma solução mais robusta, pois ela é **menos** sensível a **outliers**.
#   * Uma [Regressão Linear](https://https://oestatistico.com.br/regressao-linear-simples/) também pode ser útil, apesar de **sensível** a outliers, podem nos ajudar a inserir valores que  ajudem em uma melhor análise.
#   * Identificar a entrada **ausente** com algum valor que indique esta ausência pode ser mais informativo, quando a ausência representa valor. Por exemplo, em dados **numéricos** preencher com **zero**, e em **categóricos** criar uma categoria "**Desconhecido**".
#   * Zeros não podem ser levados em consideração em análises estatísticas.

# %% [markdown]
# #### Gráficos e Resumos Numéricos
#
# Os gráficos constituem uma das formas mais eficientes de apresentação de dados. Um gráfico é, essencialmente, uma figura constituída a partir de uma tabela, pois é quase sempre possível localizar um dado tabulado num gráfico;
#
# Enquanto as tabelas fornecem uma ideia mais precisa e possibilitam um tratamento mais rigoroso aos dados, os gráficos são mais indicados para dar uma visão mais rápida de como estão dispostas as variáveis. A qualidade na representação gráfica deve ser pautada na clareza, simplicidade e auto explicação. As técnicas gráficas desempenham um papel fundamental na AED.
#
# ![](https://github.com/paulosrl/imagens/blob/master/tipografico.png?raw=true)
#
# Fonte: http://www.each.usp.br/lauretto/SIN5008_2011/aula01/aula1

# %% [markdown]
# #### Variáveis
#
# Durante o processo de coleta de dados, não são coletados apenas a informação será analisada, muitas outras informações são coletadas com os dados brutos, algumas delas ajudarão a entender o conjunto de dados para se chegar no resultado desejado.
#
# Cada uma das características da população ou amostra, como por exemplo peso, altura e sexo é denominada de uma variável. As variáveis podem assumir valores distintos, separadas de forma básica em valores **numéricos** (variáveis quantitativas) ou **categóricos** (variáveis qualitativas).
#
# **Classificação de variáveis**
#
# **Numéricas**
#
# * **Discretas:** possuem apenas valores **inteiros**.
# Ex.: número de irmãos, número de passageiros.
# * **Contínuas:** possuem qualquer valor, incluindo  **números reais** (float). Ex.: peso, altura.
#
# **Categóricas**
#
# * **Nominais:** quando as categorias não possam ser ordenadas de alguma maneira. Ex.: nomes, cores, sexo.
#
# * **Ordinais:** nesse caso as categorias podem ser ordenadas. Ex.: tamanho (pequeno, médio, grande), classe social (baixa, média, alta), grau de instrução (básico, médio, graduação, pós-graduação).
# <br>
# <p align="center"><img src="https://raw.githubusercontent.com/paulosrl/imagens/master/variaveis.png
# "></p>
#
#
# Referência: https://dadosaocubo.com/analise-exploratoria-de-dados-com-python-parte-i/

# %% [markdown]
# #### **Medidas de tendência Central**
#
# Uma maneira de se resumir os dados de uma variável quantitativa é utilizando medidas descritivas. Estas medidas, se calculadas a partir de dados populacionais, são denominadas parâmetros e se calculadas a partir de dados amostrais são denominadas estimadores ou estatísticas.
#
# As medidas descritivas auxiliam a análise do comportamento dos dados. Tais dados são provenientes de uma população ou de uma amostra.
#
# Essas medidas descritivas são também chamadas de medida de **tendência central**. As medidas de tendência central são assim denominadas por indicarem um **ponto** em torno do qual se **concentram** os dados. Este ponto **tende** a ser o centro da **distribuição** dos dados.
#
# Recomendamos acessar o seguinte notebook ([Estatística Geral, utilizando as bibliotecas Pandas e Matplotlib do Python](https://colab.research.google.com/drive/1_M269ygp6ujFROyXJADxLnWSNgJkKlfz?authuser=1#scrollTo=UNYlDhnOFdq8)) para revisão destes conceitos de forma prática.

# %% [markdown]
# ##### Média
#
# A média aritmética é uma medida muito utilizada no cotidiano. Surge do resultado da divisão do somatório dos números dados pela quantidade de números somados. Muito utilizada, por exemplo, em campeonatos de futebol, no intuito de determinar a média de gols da rodada; em escolas, para o cálculo da média final dos alunos, etc.

# %% [markdown]
# ##### Mediana
#
# O termo “mediana” refere-se a “meio”, é o valor que divide o conjunto de dados ao **meio**, deixando os 50% menores valores de um lado e os 50% maiores valores do outro lado. Em um conjunto de informações numéricas, o valor central corresponde à mediana desse conjunto. Para que seja calculada a mediana, é necessário que esses todos os valores estejam em ordem crescente.
#
# Se no conjunto de dados houver uma quantidade ímpar de valores numéricos, a mediana será o valor central do conjunto numérico. Se a quantidade de valores for um número par, será feito o cálculo da média aritmética dos dois números centrais, o resultado será o valor da mediana.

# %% [markdown]
# ##### Média *X* Mediana
#
# É sempre necessário observar ambas as medidas, cada medida depende diretamente de como estão distribuídos os dados. No Exemplo a seguir iremo utilizar dois exemplos de conjuntos de dados.
#
# Conjunto1 = [1,2,3,4,5]
#
# Conjunto2 = [1,2,3,4,50]
#
# * Média para o primeiro conjunto de dados: 3
# * Mediana para o primeiro conjunto de dados: 3
# * Média para o segundo conjunto de dados: 12
# * Mediana para o segundo conjunto de dados: 3
#
# As duas amostras se diferenciam apenas pelo **último valor**, foi inserido um valor discrepante, chamado de **outlier**. Um *outlier* é um valor que é muito diferente dos demais, quando presentes na amostra, esses valores acabam por "contaminar" a **MÉDIA**.
#
# O outlier distorce a média, devido a este problema, quando for escolher uma medida de tendência central, é importante analisar os dados, se a média e a mediana estiverem próximas é possível que não existam valores discrepantes na amostra.
#
# Se **não houverem valores discrepantes** na amostra a melhor escolha é a **média**, mas ainda assim é importante calcular a mediana e analisar os dois valores.
#
# Caso **existam valores discrepantes** o melhor usar a **mediana**.
#
# É importante entender os valores discrepantes. Nem sempre um valor discrepante é um erro nos dados. Caso seja um erro, esse valor deverá ser eliminado da amostra e refeito os cálculos da média e mediana, analisando novamente os dois valores. Se o valor não for um erro, deve-se analisar os valores de informa separada, pois esses valores podem ser exatamente o que se busca na amostra.
#
# A mediana deve ser usada, sempre que possível, como medida representativa de distribuições fortemente assimétricas, como por exemplo a variável distribuição de renda.

# %% [markdown]
# ##### Moda
#
# Dado um conjunto de valores, a Moda desses valores será aquele que se repetir o maior número de vezes, ou seja , o valor **mais frequente** do conjunto.
#
# Essa a **única** função estatística que pode ser usada com valores **não numéricos**.
#
# Exemplo:
#
# * lista=[1,2,1,3,4,5]
#
# * m = 1
#
# O valor da moda desta lista seria o número 1, pois é o número que mais se repete.
#
# Na lista a seguir, teremos dois valores de moda, pois os dois valores 1 e 5 se repetem com a mesma frequência.
#
# * lista=[1,5,1,3,4,5]
#
# * m = 1 e 5
#
# Caso não haja repetição de nenhum valor na amostra, a moda será igual a zero.
#
# * lista=[1,2,3,4,5]
#
# * m = 0, ou seja, todos os valores só aparacem uma vez na amostra.

# %% [markdown]
# ####Desvio Padrão
#
# É um parâmetro muito usado em estatística que indica o grau de variação de um conjunto de elementos. O desvio padrão indica o quanto os dados estão afastados da média.
#
# Um valor de desvio padrão alto indica que os valores estão mais espalhados, mais longe da média, e um desvio padrão baixo indica que os valores estão mais próximos da média.
#
# Por exemplo, se medirmos a temperatura máxima durante três dias em uma cidade e obtivermos os seguintes valores, 28º, 29º e 30º, podemos dizer que a média desses três dias foi 29º. Em outra cidade, as temperaturas máximas nesses mesmos dias podem ter sido 22º, 29º e 35º. No segundo caso, a média dos três dias também foi 29º.
#
# As médias têm o mesmo valor, mas os moradores da primeira cidade viveram três dias de calor, enquanto os da segunda tiveram dois dias de calor e um de frio.
#
# Para diferenciar uma média da outra, foi criada a noção de desvio padrão, que serve para dizer o quanto os valores dos quais se extraiu a média são próximos ou distantes da própria média. No exemplo acima, o desvio padrão da segunda cidade é muito maior que o da primeira. ([IPEA](https://www.ipea.gov.br/desafios/index.php?option=com_content&view=article&id=2104:catid=28&Itemid=23))

# %% [markdown]
# ####Coeficiente de Correlação de Pearson
#
# Em muitas análises de dados deseja-se analisar a **relação entre duas medidas quantitativas**. Os coeficientes de correlação auxiliam os pesquisadores a **mensurar** essa relação.
#
# A correlação busca  **entender como uma variável se comporta em relação a outra variável**, buscando identificar se existe alguma relação entre a variabilidade de ambas. É importante observar que correlação **não implique em causalidade**, ou seja, duas variáveis correlacionadas não implicam, necessariamente, no fato do valor de uma variável ser causa da outra.
#
# **Exemplo:**
#
# * Analisar a quantidade de sorvetes vendidos relacionados a **temperatura em dias de calor acentuado**. Observa-se que a quantidade de sorvetes vendidos **aumenta**. Esta relação é chamada de **correlação positiva** entre temperaturas e quantidade de sorvetes vendidos;
#
# * **Não é possível afirmar** que se forem vendidos mais sorvetes a temperatura do dia aumentará, ou seja, não é possível afirmar que a **causa do calor** seja o **aumento das vendas**. Daí a afirmação que **correlação NÃO implica em causalidade**.

# %% [markdown]
# #####**Tipos de Correlação**
#
# * **Correlação positiva:** Esse tipo acontece quando há uma tendência crescente entre os pontos, ou seja, conforme uma variável aumenta, a outra aumenta proporcionalmente;
# * **Correlação negativa:** Aqui, a correlação se faz em uma linha decrescente. Enquanto uma variável aumenta, a outra diminui de forma proporcional;
# * **Correlação forte:** Quanto menor for a dispersão dos pontos, maior será a correlação dos dados. Com isso, a correlação forte se dá quando os dados estão altamente concentrados;
# * **Correlação fraca:** Seguindo a mesma linha da correlação anterior, quanto mais distantes estão os pontos, mais fraca é a correlação.
#
# <br>
# <p align="center"><img src="https://github.com/paulosrl/imagens/blob/master/correlacao.png?raw=true
# "></p>

# %% [markdown]
# #####**Cálculo do coeficiente de Correlação**
#
# * Mede a força da correlação e a direção dessa correlação (positiva, negativa, linear ou espalhada) entre duas variáveis, normalmente representado pela letra **r**;
#
# * Assume apenas valores entre -1 e 1;
#
# * **r = 1** : correlação perfeita positiva (direta) entre as duas variáveis;
#
# * **r = -1** : correlação negativa (indireta) perfeita entre as duas variáveis, ou seja, se uma aumenta, a outra sempre diminui;
#
# * **r = 0 :** as duas variáveis não dependem linearmente uma da outra. Porém, pode existir uma dependência não linear. Assim, o resultado deve ser investigado por outros meios.
#
# **Força da relação (r)**
#
# * 0.7 ≤ **r** ≤ 1.0: (+/-) **correlação forte**;
# * 0.3 ≤ **r** < 0.7: (+/-) **correlação moderada**;
# * 0.0 ≤ **r** < 0.3: (+/-) **correlação fraca**;
#
# **Exemplos:**
#
# <br>
# <p align="center"><img src="https://github.com/paulosrl/imagens/blob/master/Pearson.png?raw=true
# "></p>
#
# Fonte do gráfico : https://statistics.laerd.com/statistical-guides/pearson-correlation-coefficient-statistical-guide.php

# %% [markdown]
# ## Estudo de Caso - Análise dos Dados do Airbnb do Estado do Hawaii - Estados Unidos
# ---
# http://insideairbnb.com/hawaii/

# %% [markdown]
# ###Ferramentas utilizadas
# ---
#
# * [Pandas](https://pandas.pydata.org/docs/getting_started/index.html#getting-started): biblioteca para análise de dados em Python, de código aberto, licenciada por BSD, utiliza o conceito de dataframes que funcionam como uma matriz de dados, formada por linhas e colunas.
#
# * [Seaborn](https://seaborn.pydata.org/): biblioteca de visualização de dados do Python baseado no Matplotlib. Ele provê uma interface de alto nível para construção de gráficos estatísticos atrativos e informativos.
#
# * [Statistics](https://www.w3schools.com/python/module_statistics.asp) biblioteca para calcular estatísticas de dados numéricos.‎
#
# * [ploty](https://plotly.com/python/): biblioteca de visualização de dados do Python, e que permite a criação e publicação de gráficos interativos e de altíssima qualidade.
#
# * [NumPy](https://numpy.org/): biblioteca que suporta arrays e matrizes multidimensionais, possuindo uma larga coleção de funções matemáticas para trabalhar com estas estruturas.
#
# * [Matplotlib](https://matplotlib.org/): utilizada para criação de gráficos e visualizações de dados em geral.
#
# * [SciPy](https://scipy.org/scipylib/index.html): biblioteca que fornece funções numéricas fáceis de usar e eficientes, como rotinas de integração numérica, interpolação, otimização, álgebra linear e estatística.

# %%
# importar a bibliotecas
import pandas as pd
import seaborn as sns
import statistics as stats
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

#configuração da biblioteca seaborn para os gráficos
sns.set(rc={'figure.figsize':(10, 6)}) # tamanho da área de plotagem
sns.set_context("talk") # fontes maiores na visualização

# %% [markdown]
# ###Dicionário de dados
#
# * `id` - número de id gerado para identificar o imóvel
# * `name` - nome da propriedade anunciada
# * `host_id` - número de id do proprietário (anfitrião) da propriedade
# * `host_name` - Nome do anfitrião
# * `neighbourhood_group` - esta coluna não contém nenhum valor válido
# * `neighbourhood` - nome do bairro
# * `latitude` - coordenada da latitude da propriedade
# * `longitude` - coordenada da longitude da propriedade
# * `room_type` - informa o tipo de quarto que é oferecido
# * `price` - preço para alugar o imóvel
# * `minimum_nights` - quantidade mínima de noites para reservar
# * `number_of_reviews` - número de reviews que a propriedade possui
# * `last_review` - data do último review
# * `reviews_per_month` - quantidade de reviews por mês
# * `calculated_host_listings_count` - quantidade de imóveis do mesmo anfitrião
# * `availability_365` - número de dias de disponibilidade dentro de 365 dias
#
# Antes de iniciar qualquer análise, vamos verificar a cara do nosso *dataset*, analisando as 5 primeiras linhas.

# %% [markdown]
# ###Leitura dos dados

# %%
# importar o arquivo listings.csv para um DataFrame
df = pd.read_csv("http://data.insideairbnb.com/united-states/hi/hawaii/2020-12-18/visualisations/listings.csv")

# %% [markdown]
# ####Dimensão dos dados (total de linhas e colunas)

# %%
# verificar o tamanho do DataFrame
print("Linhas: ", df.shape[0])
print("Colunas: ", df.shape[1])
# Out:
# Linhas:  21319
# Colunas:  16

# %% [markdown]
# #### Nomes das colunas que compoem o Dataframe

# %%
# imprimir os nomes das colunas
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# ###Análise inicial dos dados

# %%
#5 primeiras linhas
df.head()
# Out:
#      id  ... availability_365
# 0  5269  ...              270
# 1  5387  ...              306
# 2  5389  ...              273
# 3  5434  ...              327
# 4  7896  ...              328
#
# [5 rows x 16 columns]

# %% [markdown]
# ####Tipos de dados

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21319 entries, 0 to 21318
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              21319 non-null  int64
#  1   name                            21319 non-null  object
#  2   host_id                         21319 non-null  int64
#  3   host_name                       21315 non-null  object
#  4   neighbourhood_group             21319 non-null  object
#  5   neighbourhood                   21319 non-null  object
#  6   latitude                        21319 non-null  float64
#  7   longitude                       21319 non-null  float64
#  8   room_type                       21319 non-null  object
#  9   price                           21319 non-null  int64
#  10  minimum_nights                  21319 non-null  int64
#  11  number_of_reviews               21319 non-null  int64
# ...

# %%
#5 últimas linhas
df.tail()
# Out:
#              id  ... availability_365
# 21314  47110096  ...              335
# 21315  47113121  ...                9
# 21316  47115083  ...              329
# 21317  47116165  ...                5
# 21318  47116635  ...                7
#
# [5 rows x 16 columns]

# %% [markdown]
# ####Dados ausentes

# %%
# verificando a presença e porcentagem de dados ausentes no DataFrame,
# organizando do maior para o menor em relação ao total de linhas
print('Colunas         \t      Porcentagem de valores ausentes na coluna')
(df.isnull().sum() / df.shape[0]*100).sort_values(ascending=False).round(2)
# Out:
# Colunas         	      Porcentagem de valores ausentes na coluna
# reviews_per_month                 26.00
# last_review                       26.00
# host_name                          0.02
# availability_365                   0.00
# calculated_host_listings_count     0.00
# number_of_reviews                  0.00
# minimum_nights                     0.00
# price                              0.00
# room_type                          0.00
# longitude                          0.00
# latitude                           0.00
# neighbourhood                      0.00
# neighbourhood_group                0.00
# host_id                            0.00
# name                               0.00
# id                                 0.00
# dtype: float64

# %% [markdown]
# ####Verificando linhas duplicadas

# %%
# verificando se existem linhas duplicadas no dataset
print('Total de linhas duplicadas:',df.duplicated().sum())
# Out:
# Total de linhas duplicadas: 0

# %% [markdown]
# ####Resumo estatístico dos dados

# %%
#resumo estatístico
df.describe().transpose()
# Out:
#                                   count  ...           max
# id                              21319.0  ...  4.711664e+07
# host_id                         21319.0  ...  3.807074e+08
# latitude                        21319.0  ...  2.222907e+01
# longitude                       21319.0  ... -1.548230e+02
# price                           21319.0  ...  2.500000e+04
# minimum_nights                  21319.0  ...  3.650000e+02
# number_of_reviews               21319.0  ...  7.390000e+02
# reviews_per_month               15775.0  ...  1.589000e+01
# calculated_host_listings_count  21319.0  ...  4.150000e+02
# availability_365                21319.0  ...  3.650000e+02
#
# [10 rows x 8 columns]

# %% [markdown]
# ### Distribuição dos dados das colunas numéricas

# %%
# plotar o histograma das colunas numéricas
# número de barras do histograma
# figzise(largura,altura) do gráfico
df.hist(bins=15, figsize=(25,15));

# %% [markdown]
# ###Correlação entre variáveis

# %%
fig = px.scatter(df, x="price", y="minimum_nights",size='minimum_nights',color="room_type",
                 color_discrete_sequence=["red", "blue","yellow","green"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="19265e4c-b25e-40ac-8628-f994c8a35197" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("19265e4c-b25e-40ac-8628-f994c8a35197")) {
#                     Plotly.newPlot(
#                         '19265e4c-b25e-40ac-8628-f994c8a35197',
# ...

# %% [markdown]
# ####Cálculo do coeficiente de Correlação de Pearson

# %%
corr, _ = pearsonr(df['price'], df['minimum_nights'])
print('Cálculo do coeficiente de Correlação de Pearson: %.3f' % corr)
# Out:
# Cálculo do coeficiente de Correlação de Pearson: 0.001

# %% [markdown]
# Em uma primeira análise não há correlaçaõ entre price e minimum_nights.

# %% [markdown]
# ### Verificar se existem outliers nas colunas numéricas que serão analisadas
#
# **Resumo estatístico das colunas selecionadas**

# %%
# ver o resumo estatístico das colunas numéricas
df[['price', 'minimum_nights']].describe()
# Out:
#               price  minimum_nights
# count  21319.000000    21319.000000
# mean     406.008631        8.117313
# std     1140.455807       23.301893
# min        0.000000        1.000000
# 25%      139.000000        1.000000
# 50%      221.000000        3.000000
# 75%      364.000000        5.000000
# max    25000.000000      365.000000

# %% [markdown]
# **Comparando a Média e Mediana das colunas selecionadas**

# %%
#Média e mediana de price
print('Média de price   : {:.2f}'.format(df['price'].mean()))
print('Mediana de price: {:.2f}'.format(df['price'].median()))
# Out:
# Média de price   : 406.01
# Mediana de price: 221.00

# %%
#Média e mediana de minimum_nights
print('Média de minimum_nights  : {:.2f}'.format(df['minimum_nights'].mean()))
print('Mediana de minimum_nights: {:.2f}'.format(df['minimum_nights'].median()))
# Out:
# Média de minimum_nights  : 8.12
# Mediana de minimum_nights: 3.00

# %% [markdown]
# **Calculando a moda das colunas selecionadas**

# %%
#cálculo da moda
print('Moda para a variável price:',stats.mode(df['price']))
print('Moda para a variável minimum_nights:',stats.mode(df['minimum_nights']))
# Out:
# Moda para a variável price: 150
# Moda para a variável minimum_nights: 1

# %% [markdown]
# ###Resumo da análise dos dados brutos

# %% [markdown]
# O resumo estatístico acima, nos permite realizar algumas observações descritas a seguir:
#
# **Para a coluna price:**
#
# * A média está em 406, porém observamos um desvio padrão (std) muito alto de 1140,45;
#
# * Média e mediana não estão próximas, sendo respectivamente 406,01 e 221,00;
#
# * O valor mínimo está igual a 0;
#
# * O valor máximo é de 25.000;
#
# * 75% do valores são menores ou iguais 364;
#
# * 50% do valores são menores ou iguais 221;
#
# * 25% do valores são menores ou iguais 139;
#
# * O valor que mais se repete (moda) é igual a 150.
#
# **Para a coluna minimum_nights:**
#
# * A média está em 8,12, porém observamos um desvio padrão (std) muito alto de 23,30;
#
# * Média e mediana não estão próximas, sendo respectivamente 8,12 e 3;
#
# * O valor mínimo está igual a 1;
#
# * O valor máximo está igual a 365;
#
# * 75% dos valores são menores ou iguais 5;
#
# * 50% dos valores são menores ou iguais 3;
#
# * 25% dos valores são valores iguais a 1;
#
# * O valor que mais se repete (moda) é igual a 1.

# %% [markdown]
# ### Gráficos com resumo estatístico dos dados
#
# Recomendamos usar ao menos dois  gráficos para mostrar como está a distribuição dos dados (resumo estatístico), são eles os **Boxplots** e os **Histogramas**.
#
# Acesse o notebook ([Estatística Geral, utilizando as bibliotecas Pandas e Matplotlib do Python](https://colab.research.google.com/drive/1_M269ygp6ujFROyXJADxLnWSNgJkKlfz?authuser=1#scrollTo=UNYlDhnOFdq8)) para revisão dos conceitos relacionados a estes gráficos, com exemplos.

# %% [markdown]
# **Histograma e boxplots para a coluna price**

# %%
#plotando o histograma apenas para a coluna price
fig = px.histogram(df,x="price",title="Distribuição de price",nbins=1200, width=1000,height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c73df8ae-b5b0-4a6a-8605-c3821186e53e" class="plotly-graph-div" style="height:500px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c73df8ae-b5b0-4a6a-8605-c3821186e53e")) {
#                     Plotly.newPlot(
#                         'c73df8ae-b5b0-4a6a-8605-c3821186e53e',
# ...

# %%
# realizando uma análise através do método Boxplot para price
fig = px.box(df,y="price",title="Distribuição de price",width=300,height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="bb3c275b-156f-4b63-8dd1-4bc0419c663d" class="plotly-graph-div" style="height:500px; width:300px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bb3c275b-156f-4b63-8dd1-4bc0419c663d")) {
#                     Plotly.newPlot(
#                         'bb3c275b-156f-4b63-8dd1-4bc0419c663d',
# ...

# %%
fig = px.box(df,y="price", points="all",title="Distribuição dos dados x histograma de price",width=900,height=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="58b7fdb6-64b3-4465-8678-e90846e7b3d3" class="plotly-graph-div" style="height:800px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("58b7fdb6-64b3-4465-8678-e90846e7b3d3")) {
#                     Plotly.newPlot(
#                         '58b7fdb6-64b3-4465-8678-e90846e7b3d3',
# ...

# %% [markdown]
# ### Cálculo do IQR
#
# Para tratar dos outliers desse conjunto de dados, iremos analisar a **distribuição estatística**, plotar boxplots e calcular os limites (inferior e superior) utilizando a regra da [variação interquartil](https://escoladedados.org/tutoriais/analise-com-estatistica-descritiva-para-leigos/).
#
# **VARIAÇÃO INTERQUARTIL = Q3-Q1**
#
# Onde Q3 (terceiro quartil) representa 75% dos dados e Q1 (primeiro quartil) representa 25% dos dados
# # IQR = Q3 - Q1
#
# Tanto o desvio padrão quanto a variância dependem da média, portanto, são afetados por valores extremos. Mas, a Variação interquartil (IQR em inglês), é uma medida de dispersão baseada na mediana, que funciona de maneira muito mais eficiente na presença de outliers, pois é pouco afetada pelo outliers.
#
# Antes da remoção dos outliers será necessário:
#
# * Definir o Q1 e Q3 para as variáveis que serão limpas.
# * Calcular o IQR para as variáveis.
# * Definir o limite superior e inferior para cortar os outliers.

# %% [markdown]
# **IQR para a coluna price**

# %%
# identificando os outliers para a variável price
#cálculo do IQR
coluna='price'
q3, q1 = np.percentile(df[coluna], [75 ,25])
IQR = q3 - q1
#limite inferior é -1.5 vezes o valor do IQR
min = q1 - (IQR*1.5)
#limite superior é +1.5 vezes o valor do IQR
max = q3 + (IQR*1.5)
print('IQR da variável '+coluna+': ', IQR)
print('Limite inferior de '+coluna+':', min)
print('Limite superior de '+coluna+':', max)
# Out:
# IQR da variável price:  225.0
# Limite inferior de price: -198.5
# Limite superior de price: 701.5

# %% [markdown]
# Resumo dos dados após a análise do IQR

# %%
total_acima_superior = len(df[df.price > max])
print("Total de linhas do dataset: "+str(df.shape[0]))
print("Entradas acima de "+str(max)+": "+str(total_acima_superior))
print("{:.2f}% do dataset".format((total_acima_superior / df.shape[0])*100))
# Out:
# Total de linhas do dataset: 21319
# Entradas acima de 701.5: 1973
# 9.25% do dataset

# %% [markdown]
# **Histograma e boxplots para a coluna minimum_nights**

# %%
#plotando o histograma apenas para a coluna minimum_nights
fig = px.histogram(df,x="minimum_nights",title="Distribuição de minimum_night",nbins=1000, width=1000,height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0202dde9-0d10-4822-8259-67d9db7b6657" class="plotly-graph-div" style="height:500px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0202dde9-0d10-4822-8259-67d9db7b6657")) {
#                     Plotly.newPlot(
#                         '0202dde9-0d10-4822-8259-67d9db7b6657',
# ...

# %%
# realizando uma análise através do método Boxplot para minimum_nights
fig = px.box(df,y="minimum_nights",title="Distribuição de minimum_nights",width=300,height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="18df9329-eb15-4c17-bb9f-787949246cbd" class="plotly-graph-div" style="height:500px; width:300px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("18df9329-eb15-4c17-bb9f-787949246cbd")) {
#                     Plotly.newPlot(
#                         '18df9329-eb15-4c17-bb9f-787949246cbd',
# ...

# %%
fig = px.box(df,y="minimum_nights", points="all",title="Distribuição dos dados x histograma minimum_nights",width=900,height=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="231f207b-eaf5-4876-ba16-ec5c92695c96" class="plotly-graph-div" style="height:800px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("231f207b-eaf5-4876-ba16-ec5c92695c96")) {
#                     Plotly.newPlot(
#                         '231f207b-eaf5-4876-ba16-ec5c92695c96',
# ...

# %% [markdown]
# **IQR para a coluna minimum_nights**

# %%
# identificando os outliers para a variável price
#cálculo do IQR
coluna='minimum_nights'
q3, q1 = np.percentile(df[coluna], [75 ,25])
IQR = q3 - q1
#limite inferior é -1.5 vezes o valor do IQR
min = q1 - (IQR*1.5)
#limite superior é +1.5 vezes o valor do IQR
max = q3 + (IQR*1.5)
print('IQR da variável '+coluna+': ', IQR)
print('Limite inferior de '+coluna+':', min)
print('Limite superior de '+coluna+':', max)
# Out:
# IQR da variável minimum_nights:  4.0
# Limite inferior de minimum_nights: -5.0
# Limite superior de minimum_nights: 11.0

# %% [markdown]
# Resumo dos dados após a análise do IQR

# %%
total_acima_superior = len(df[df.minimum_nights > max])
print("Total de linhas do dataset: "+str(df.shape[0]))
print("Entradas acima de "+str(max)+": "+str(total_acima_superior))
print("{:.2f}% do dataset".format((total_acima_superior / df.shape[0])*100))
# Out:
# Total de linhas do dataset: 21319
# Entradas acima de 11.0: 2242
# 10.52% do dataset

# %% [markdown]
# ### Avaliação do resultados da análise dos dados brutos
#
# Nesta etapa, deverá ser avaliado o que ficará para ser analisado. É importante conhecer os dados para sejam tomadas as decisões corretas. Neste exemplo as colunas **price** e **minimum_nights** são as colunas que irão nortear a decisão da etapa seguinte.
#
# Devemos preservar o dataset original para efeito de comparação com o novo dataset que gerá criado após a limpeza dos dados.
#
# * Para ambas as colunas serão eliminados todos os valores menores ou iguais a zero;
# * Para a coluna **price**, o limite superior calculado é de 701.5, neste estudo de caso serão eliminados todos os valores **acima** deste valor, que representam **9.25%** do dataset;
# * Para a coluna **minimum_nights**, o limite superior calculado é de 4, neste estudo de caso serão eliminados todos os valores **acima** deste valor, que representam **10.52%** do dataset;

# %% [markdown]
# **Análise Bivariada**

# %%
#análise bivariada
cor= df.corr()
pos=1
plt.figure(figsize=(15,8))
sns.heatmap(cor,xticklabels=cor.columns,yticklabels=cor.columns,annot=True,cmap='magma');

# %% [markdown]
# ### Limpando Outliers

# %%
# limpando o dataset (faz uma cópia do dataset original e armazena em df_nylimpo)
df_limpo = df.copy()
corte_price=701.5
corte_minimum_nights=11

#todos os valores de price e corte_minimum_nights iguais a zero serão eliminados
df_limpo.drop(df_limpo[df_limpo.price <= 0.0].index, axis=0, inplace=True)
df_limpo.drop(df_limpo[df_limpo.minimum_nights <= 0.0].index, axis=0, inplace=True)

#o limite superior calculado é de 701.5, todos os valores acima deste valor serão eliminados
#o limite superior calculado é de 11, todos os valores acima deste valor serão eliminados
df_limpo.drop(df_limpo[df_limpo.price > corte_price].index, axis=0, inplace=True)
df_limpo.drop(df_limpo[df_limpo.minimum_nights > corte_minimum_nights].index, axis=0, inplace=True)

#o limite superior calculado é de 11, todos os valores acima deste valor serão eliminados
print('Linhas antes da limpeza: ', df.shape)
print('Linhas após a limpeza: ',df_limpo.shape)
# Out:
# Linhas antes da limpeza:  (21319, 16)
# Linhas após a limpeza:  (17226, 16)

# %% [markdown]
# ### Avaliação dos resultados após a primeira etapa de análise dos dados brutos.

# %% [markdown]
# #### Resumo estatístico dos dados

# %%
# ver o resumo estatístico das colunas numéricas
df_limpo[['price', 'minimum_nights']].describe()
# Out:
#               price  minimum_nights
# count  17226.000000    17226.000000
# mean     246.057587        2.872576
# std      141.126823        1.770674
# min       10.000000        1.000000
# 25%      140.000000        1.000000
# 50%      211.000000        3.000000
# 75%      319.000000        4.000000
# max      701.000000       11.000000

# %% [markdown]
# #### Distribuição dos dados das colunas numéricas

# %%
# plotar o histograma das colunas numéricas
# número de barras do histograma
# figzise(largura,altura) do gráfico
df_limpo.hist(bins=15, figsize=(25,15));

# %% [markdown]
# ####Correlação entre variáveis

# %%
fig = px.scatter(df_limpo, x="price", y="minimum_nights",size='minimum_nights',color="room_type",
                 color_discrete_sequence=["red", "blue","yellow","green"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0b378801-d98a-4d34-b4d4-52a1b6bc3fa7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0b378801-d98a-4d34-b4d4-52a1b6bc3fa7")) {
#                     Plotly.newPlot(
#                         '0b378801-d98a-4d34-b4d4-52a1b6bc3fa7',
# ...

# %% [markdown]
# #####Cálculo do coeficiente de Correlação de Pearson

# %%
corr, _ = pearsonr(df_limpo['price'], df_limpo['minimum_nights'])
print('Cálculo do coeficiente de Correlação de Pearson: %.3f' % corr)
# Out:
# Cálculo do coeficiente de Correlação de Pearson: 0.240

# %% [markdown]
# Mesmo após o corte dos dados podemos afirmar que não há correlaçaõ entre price e minimum_nights.

# %% [markdown]
# ####Gráficos com resumo estatístico dos dados

# %% [markdown]
# **Histograma e boxplots para a coluna price**

# %%
#plotando o histograma apenas para a coluna price
fig = px.histogram(df_limpo,x="price",title="Distribuição de price",nbins=100, width=1200,height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="30853dcd-22b5-46cb-a50b-0f8da2898bcc" class="plotly-graph-div" style="height:500px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("30853dcd-22b5-46cb-a50b-0f8da2898bcc")) {
#                     Plotly.newPlot(
#                         '30853dcd-22b5-46cb-a50b-0f8da2898bcc',
# ...

# %%
# realizando uma análise através do método Boxplot para price
fig = px.box(df_limpo,y="price",title="Distribuição de price",width=300,height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="559b3791-23fe-44ab-9858-5d81b7fcf3a0" class="plotly-graph-div" style="height:500px; width:300px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("559b3791-23fe-44ab-9858-5d81b7fcf3a0")) {
#                     Plotly.newPlot(
#                         '559b3791-23fe-44ab-9858-5d81b7fcf3a0',
# ...

# %%
fig = px.box(df_limpo,y="price", points="all",title="Distribuição dos dados x histograma de price",width=900,height=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c17ace47-24a4-4d7e-81dc-891f430093cb" class="plotly-graph-div" style="height:800px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c17ace47-24a4-4d7e-81dc-891f430093cb")) {
#                     Plotly.newPlot(
#                         'c17ace47-24a4-4d7e-81dc-891f430093cb',
# ...

# %% [markdown]
# **Histograma e boxplots para a coluna minimum_nights**

# %%
#plotando o histograma apenas para a coluna minimum_nights
fig = px.histogram(df_limpo,x="minimum_nights",title="Distribuição de minimum_night",nbins=30, width=500,height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cba870d2-f4ec-4834-abc4-66d34a6e27a0" class="plotly-graph-div" style="height:500px; width:500px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cba870d2-f4ec-4834-abc4-66d34a6e27a0")) {
#                     Plotly.newPlot(
#                         'cba870d2-f4ec-4834-abc4-66d34a6e27a0',
# ...

# %%
# realizando uma análise através do método Boxplot para minimum_nights
fig = px.box(df_limpo,y="minimum_nights",title="Distribuição de minimum_nights",width=300,height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="87b36f8f-262e-439f-bbe8-9c6d16d33654" class="plotly-graph-div" style="height:500px; width:300px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("87b36f8f-262e-439f-bbe8-9c6d16d33654")) {
#                     Plotly.newPlot(
#                         '87b36f8f-262e-439f-bbe8-9c6d16d33654',
# ...

# %%
fig = px.box(df_limpo,y="minimum_nights", points="all",title="Distribuição dos dados x histograma minimum_nights",width=900,height=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4fdb1e77-999d-482c-9bfd-217d6eeb5e38" class="plotly-graph-div" style="height:800px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4fdb1e77-999d-482c-9bfd-217d6eeb5e38")) {
#                     Plotly.newPlot(
#                         '4fdb1e77-999d-482c-9bfd-217d6eeb5e38',
# ...

# %% [markdown]
# ##Conclusão
#
# * Após analisar os dados brutos deste estudo de caso, foram escolhidas duas variáveis para uma análise mais detalhada, price e minimum_nights. As duas variáveis possuíam muitos outliers, por isso foi utilizada uma técnica de eliminação de outliers chamada de IQR score.
#
# * Na aplicação do IQR score, decidiu-se por eliminar todos as linhas do dataset que possuíam price igual a zero e price maior 701,5, as linhas com valores acima de 701,5 representavam apenas 9,25% dos dados.
#
# * Em relação a variável minimum_nights, foram eliminadas as linhas com valores iguais a zero e com valores acima de 11, utilizando-se também a técnica de IQR score. As linhas eliminadas representavam 10,52%.
#
# * Na análise de correlação, para este estudo de caso, não foi possível achar correlação entre as variáveis price e minimum_nights.
#
# * Outras análises poderiam ser feitas por faixas de valores, levando em consideração o perfil do imóvel que se deseja alugar.
#
# * O objetivo nesta análise, foi mostrar as principais ferramentas que são utilizadas na análise exploratória de dados.
